# %%
# Importing Libraries
import ast
import pandas as pd
import seaborn as sns
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
df_exploded=df.explode('job_skills')

# %%
df_exploded=df_exploded[df_exploded['job_title_short']=='Data Scientist']

# %%
df_exploded['job_month']=df_exploded['job_posted_date'].dt.month

# %%
df_pivot=df_exploded.pivot_table(
    index='job_month',
    columns='job_skills',
    aggfunc='size',fill_value=0
)

# %%
df_pivot.loc['total_value']=df_pivot.sum()

# %%
df_pivot=df_pivot[df_pivot.loc['total_value'].sort_values(ascending=False).index]

# %%
df_pivot=df_pivot.drop('total_value',axis=0)

# %%
df_pivot
# Out:
# job_skills  python   sql     r   sas  tableau   aws  spark  azure  tensorflow  \
# job_month
# 1            13998  9811  7566  3842     3446  3253   3222   2582        2316
# 2             9551  6600  5064  2644     2566  2089   2085   1716        1525
# 3             9210  6374  4971  2480     2456  2092   1992   1727        1405
# 4             9135  6270  4873  2444     2447  2055   1905   1665        1546
# 5             8029  5583  4228  2244     2271  1921   1716   1442        1271
# 6             9338  6473  5019  2282     2432  2173   2072   1739        1580
# 7             9400  6678  5029  2300     2547  2207   1972   1845        1535
# 8            11193  8026  6089  3100     3013  2571   2466   2130        1972
# 9             8393  5748  4153  2224     2062  1923   1820   1704        1462
# 10            8777  5917  4415  2032     2172  2023   1747   1760        1516
# 11            9051  6271  4485  2182     2172  2117   1785   1806        1616
# 12            7636  5231  3674  1760     1861  1832   1504   1548        1409
#
# job_skills  excel  ...  huggingface  fastify  esquisse  workfront  \
# job_month          ...
# 1            2132  ...            0        0         0          0
# 2            1453  ...            0        0         1          0
# 3            1440  ...            0        0         0          1
# 4            1456  ...            0        2         0          0
# 5            1202  ...            0        0         0          0
# 6            1324  ...            0        1         1          0
# 7            1425  ...            1        0         0          0
# 8            1795  ...            0        0         0          0
# 9            1352  ...            3        0         0          0
# 10           1389  ...            0        0         0          1
# 11           1468  ...            0        0         0          0
# 12           1109  ...            0        0         0          0
#
# job_skills  play framework  nuxt.js  mattermost  shogun  sqlserver  wimi
# job_month
# 1                        0        0           0       0          0     0
# 2                        0        0           0       0          0     0
# 3                        0        0           0       1          0     0
# 4                        0        0           0       0          0     0
# 5                        0        0           0       0          0     0
# 6                        0        0           0       0          0     0
# 7                        0        0           0       0          0     0
# 8                        1        0           0       0          0     0
# 9                        0        0           0       0          0     0
# 10                       1        0           1       0          0     0
# 11                       0        1           0       0          1     0
# 12                       0        0           0       0          0     1
#
# [12 rows x 237 columns]

# %%
df['month']=df['job_posted_date'].dt.month

# %%
df=df[df['job_title_short']=='Data Scientist'].groupby('month').size()

# %%
df_pivot=df_pivot.div(df/100,axis=0)

# %%
df_pivot
# Out:
# job_skills     python        sql          r        sas    tableau        aws  \
# job_month
# 1           67.427746  47.259152  36.445087  18.506744  16.599229  15.669557
# 2           68.461042  47.308437  36.298473  18.952046  18.392947  14.973837
# 3           67.875304  46.974722  36.634977  18.276955  18.100081  15.417496
# 4           67.601569  46.399763  36.061570  18.086287  18.108488  15.207578
# 5           68.361005  47.535121  35.998297  19.106003  19.335888  16.355896
# 6           68.586118  47.543151  36.863753  16.760925  17.862651  15.960338
# 7           66.304578  47.104465  35.472949  16.223461  17.965719  15.567468
# 8           65.903203  47.256241  35.851390  18.252473  17.740226  15.137777
# 9           61.817780  42.336304  30.588495  16.380644  15.187449  14.163659
# 10          62.023885  41.813299  31.199209  14.359409  15.348739  14.295809
# 11          63.649789  44.099859  31.540084  15.344585  15.274262  14.887482
# 12          63.506321  43.504657  30.555556  14.637392  15.477379  15.236194
#
# job_skills      spark      azure  tensorflow      excel  ...  huggingface  \
# job_month                                                ...
# 1           15.520231  12.437380   11.156069  10.269750  ...     0.000000
# 2           14.945165  12.300194   10.931116  10.415024  ...     0.000000
# 3           14.680522  12.727541   10.354484  10.612425  ...     0.000000
# 4           14.097536  12.321468   11.440835  10.774809  ...     0.000000
# 5           14.610473  12.277565   10.821626  10.234142  ...     0.000000
# 6           15.218509  12.772677   11.604848   9.724568  ...     0.000000
# 7           13.909854  13.014037   10.827396  10.051492  ...     0.007054
# 8           14.519548  12.541215   11.610928  10.568771  ...     0.000000
# 9           13.405023  12.550637   10.768211   9.958017  ...     0.022096
# 10          12.345417  12.437284   10.713024   9.815561  ...     0.000000
# 11          12.552743  12.700422   11.364276  10.323488  ...     0.000000
# 12          12.508317  12.874251   11.718230   9.223220  ...     0.000000
#
# job_skills   fastify  esquisse  workfront  play framework   nuxt.js  \
# job_month
# 1           0.000000  0.000000   0.000000        0.000000  0.000000
# 2           0.000000  0.007168   0.000000        0.000000  0.000000
# 3           0.000000  0.000000   0.007370        0.000000  0.000000
# 4           0.014801  0.000000   0.000000        0.000000  0.000000
# 5           0.000000  0.000000   0.000000        0.000000  0.000000
# 6           0.007345  0.007345   0.000000        0.000000  0.000000
# 7           0.000000  0.000000   0.000000        0.000000  0.000000
# 8           0.000000  0.000000   0.000000        0.005888  0.000000
# 9           0.000000  0.000000   0.000000        0.000000  0.000000
# 10          0.000000  0.000000   0.007067        0.007067  0.000000
# 11          0.000000  0.000000   0.000000        0.000000  0.007032
# 12          0.000000  0.000000   0.000000        0.000000  0.000000
#
# job_skills  mattermost   shogun  sqlserver      wimi
# job_month
# 1             0.000000  0.00000   0.000000  0.000000
# 2             0.000000  0.00000   0.000000  0.000000
# 3             0.000000  0.00737   0.000000  0.000000
# 4             0.000000  0.00000   0.000000  0.000000
# 5             0.000000  0.00000   0.000000  0.000000
# 6             0.000000  0.00000   0.000000  0.000000
# 7             0.000000  0.00000   0.000000  0.000000
# 8             0.000000  0.00000   0.000000  0.000000
# 9             0.000000  0.00000   0.000000  0.000000
# 10            0.007067  0.00000   0.000000  0.000000
# 11            0.000000  0.00000   0.007032  0.000000
# 12            0.000000  0.00000   0.000000  0.008317
#
# [12 rows x 237 columns]

# %%
df_pivot=df_pivot.reset_index()
df_pivot['month']=pd.to_datetime(df_pivot['job_month'],format='%m').dt.month_name()

# %%
df_pivot=df_pivot.set_index('month')

# %%
df_pivot=df_pivot.drop(columns='job_month')

# %%
# Select top 5 skills
df_plot = df_pivot.iloc[:, :5]

# Theme
sns.set_theme(
    style="whitegrid",
    context="talk"
)

# Figure
plt.figure(figsize=(12, 7))

# Plot
sns.lineplot(
    data=df_plot,
    linewidth=3
)

# Formatting
plt.title(
    "Trend of Skills Demanded for Data Scientists Globally",
    fontsize=18,
    pad=20,
    weight='bold'
)

plt.xlabel("Month", fontsize=13)
plt.ylabel("Percentage of Job Postings", fontsize=10)

# Rotate month labels
plt.xticks(rotation=45, ha='right')

plt.legend(
    title="Skills",
    bbox_to_anchor=(1.02, 1),
    loc="upper left",
    frameon=True
)

plt.grid(alpha=0.3)

sns.despine()

plt.tight_layout()
plt.show()
