# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

df['job_skills'] = df['job_skills'].apply(
    lambda x: ast.literal_eval(x) if pd.notna(x) else x
)

# %%
df=df.explode('job_skills')

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# ...                      ...
# 785739         Data Engineer
# 785739         Data Engineer
# 785739         Data Engineer
# 785740     Software Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# ...                                                   ...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# ...

# %%
df_temp=df.groupby(['job_title_short','job_skills']).size()

# %%
df_temp=df_temp.reset_index()

# %%
df_temp["skill_count"]=df_temp[0]

# %%
df_temp=df_temp.drop(columns=[0])

# %%
job_list=['Data Analyst','Data Engineer','Data Scientist']

# %%
fig,ax=plt.subplots(3,1)
for i,job_title in enumerate(job_list): 
    df_temp[df_temp['job_title_short']==job_title].sort_values(by="skill_count",ascending=False).head().plot(kind='barh',x="job_skills",y="skill_count",ax=ax[i],title=job_title,legend=False)
    plt.tight_layout()
    ax[i].set_xlim(0,120000) 
    ax[i].set_ylabel("")
    ax[i].invert_yaxis()
